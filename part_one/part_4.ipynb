# %% [markdown]
# # Простая нейронная сеть

# %%
import numpy             as np
import matplotlib.pyplot as plt
import math

X = np.arange(0,30,1)
y = np.sin(X)

fig = plt.figure()  

plt.plot(X,y)
plt.show()

# %%
layer_0 = np.random.normal(size=300).reshape(30,10)

# %%
gradient = 0.0
error    = 0.0
output   = 0.0
eta      = 0.001
alpha    = 0.01


def sigmoid(x):
    return 1/(1+math.exp(-x*1.0))
