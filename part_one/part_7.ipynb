# %%
import tensorflow        as tf
import pandas            as pd
import matplotlib.pyplot as plt
import seaborn           as sns

# %%
df=pd.read_csv('../datasets/iris.csv', sep=',')

npdf   = df.values
target = npdf[1:,5:]

X = npdf[1:,1]
Y = npdf[1:,2]

# %%
fig = plt.figure()  

plt.scatter(X,Y)

plt.show()

# %%
df["Species"].value_counts()
# Out:
# versicolor    50
# setosa        50
# virginica     50
# Name: Species, dtype: int64

# %%
sns.set(style="white", color_codes=True)
sns.FacetGrid(df,hue = "Species", size=5).map(plt.scatter,x=X,y=Y).add_legend()
